# %% [markdown]
# # Qubic - Finite - Medio BDP

# %%
from IPython.display import JSON
JSON({
    "NumLinks": 1,
    "Links": [
        {
            "Link-type": "LMS",
            "Band": "Ka_truqi_5sec",
            "DataRate": 60,
            "Delay": 10,
            "ErrorRate": 0,
            "Mode": "OTROS",
            "MTU": 1460,
            "DropTailQueue": 90000,
            "Background": false
        }
    ]
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 14
#       1 from IPython.display import JSON
#       2 JSON({
#       3     "NumLinks": 1,
#       4     "Links": [
#       5         {
#       6             "Link-type": "LMS",
#       7             "Band": "Ka_truqi_5sec",
#       8             "DataRate": 60,
#       9             "Delay": 10,
#      10             "ErrorRate": 0,
#      11             "Mode": "OTROS",
#      12             "MTU": 1460,
#      13             "DropTailQueue": 90000,
# ---> 14             "Background": false
#      15         }
#      16     ]
#      17 })
#
# NameError: name 'false' is not defined

# %%
from ast import Del
from fileinput import filename
import os
import numpy as np
import matplotlib.pyplot as plt


foldername= "./Qubic_finito/logCwnd.log"

with open (foldername) as datatoread:
     cwnd = np.loadtxt(datatoread)

foldername= "./Qubic_finito/logBuffer.log"
with open (foldername) as datatoread:
     buff = np.loadtxt(datatoread)

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(cwnd[:,0], cwnd[:,1], 'g-')
ax2.plot(buff[:,0], buff[:,1], 'b-')

ax1.set_xlabel('Time (s)')
ax1.set_ylabel('CWND (#)', color='g')
ax2.set_ylabel('Buffer (pkts)', color='b')

plt.show()

# %% [markdown]
# # Reno - Finite - Medio BDP

# %%
foldername= "./Reno_finito_MedioBDP/logCwnd.log"

with open (foldername) as datatoread:
     cwnd = np.loadtxt(datatoread)

foldername= "./Reno_finito_MedioBDP/logBuffer.log"
with open (foldername) as datatoread:
     buff = np.loadtxt(datatoread)

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(cwnd[:,0], cwnd[:,1], 'g-')
ax2.plot(buff[:,0], buff[:,1], 'b-')

ax1.set_xlabel('Time (s)')
ax1.set_ylabel('CWND (#)', color='g')
ax2.set_ylabel('Buffer (pkts)', color='b')

plt.show()
